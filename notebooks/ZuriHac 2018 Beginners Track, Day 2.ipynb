-- %%
import Data.Char
isPalindrome :: String -> Bool
isPalindrome xs = xs == reverse xs

ignoreSpaces :: String -> String
ignoreSpaces xs = (concat . words) xs

ignoreCaps :: String -> String
ignoreCaps xs = map toLower xs

ignoreCapsAndSpaces :: String -> String
ignoreCapsAndSpaces xs = (ignoreCaps . ignoreSpaces) xs

word <- getLine
print (isPalindrome (ignoreCapsAndSpaces word))
-- Out:
-- False

-- %%
:opt no-pager

-- %%
:info Either
-- Out:
-- data Either a b = Left a | Right b 	-- Defined at <interactive>:1:1
-- instance [safe] Functor (Either a) -- Defined at <interactive>:2:10

-- %%
isWord :: String -> Maybe String
isWord "" = Nothing
isWord xs = case all isAlpha xs of
    True -> Just "OK"
    False -> Just "Nope"

-- %%
fromJust $ isWord " "
-- Out:
-- "Nope"

-- %%
import Data.Maybe
:type fromJust
-- Out:
-- fromJust :: forall a. Maybe a -> a

-- %%
:t getLine
-- Out:
-- getLine :: IO String

-- %%
maybeMap :: (a -> b) -> Maybe a -> Maybe b
maybeMap _ Nothing = Nothing
maybeMap f (Just x) = Just (f x)

-- %%
maybeMap (+2) (Just 3)
-- Out:
-- Just 5

-- %%
:t fmap
-- Out:
-- fmap :: forall (f :: * -> *) a b. Functor f => (a -> b) -> f a -> f b

-- %%
:type fmap reverse getLine
-- Out:
-- fmap reverse getLine :: IO [Char]

-- %%
data Maybe a = Nothing | Just a

instance Functor Maybe where
    -- fmap :: (a -> b) -> Maybe a -> Maybe b
    fmap _ Nothing = Nothing
    fmap f (Just x) = Just $ f x

-- %%
data Either a b = Left a | Right b

instance Functor (Either a) where
    -- fmap :: (x -> y) -> (Either a) x -> (Either a) y 
    fmap _ (Left x) = Left x
    fmap f (Right y) = Right $ f y

-- %%
:kind Either
-- Out:
-- Either :: * -> * -> *

-- %%
:kind (,)
-- Out:
-- (,) :: * -> * -> *

-- %%
data Pair a b = Pair a b

instance Functor (Pair a) where
    fmap f (Pair x y) = Pair x (f y)

-- %%
:kind IO
-- Out:
-- IO :: * -> *

-- %%
:t print
-- Out:
-- print :: forall a. Show a => a -> IO ()

-- %%
:t getLine
-- Out:
-- getLine :: IO String

-- %%
-- Syntactic sugar:
main :: IO ()
main = do
    word <- getLine
    print (isWord word)
-- Out:
-- Just "Nope"

-- %%
:type (>>=)
-- Monad m => m a -> (a -> m b) -> m b
-- Out:
-- (>>=) :: forall (m :: * -> *) a b. Monad m => m a -> (a -> m b) -> m b

-- %%
getLine >>= (print . isWord)
--      m a           a -> m b
--     IO String      String -> IO Bool
-- Out:
-- Just "Nope"

-- %%
instance Monad (Either a) where
    return = pure
    (>>=) (Left x) _ = Left x
    (>>=) (Right y) f = f y
-- Out:
-- <interactive>:1:10: error:
--     • No instance for (Applicative (Either a)) arising from the superclasses of an instance declaration
--       There are instances for similar types: instance Applicative (IHaskellPrelude.Either e) -- Defined in ‘Data.Either’
--     • In the instance declaration for ‘Monad (Either a)’
-- <interactive>:2:14: error:
--     • No instance for (Applicative (Either a)) arising from a use of ‘pure’
--       There are instances for similar types: instance Applicative (IHaskellPrelude.Either e) -- Defined in ‘Data.Either’
--     • In the expression: pure
--       In an equation for ‘return’: return = pure
--       In the instance declaration for ‘Monad (Either a)’

-- %%
:type (<*>)
-- Out:
-- (<*>) :: forall (f :: * -> *) a b. Applicative f => f (a -> b) -> f a -> f b

-- %%
:info Maybe
-- Out:
-- data Maybe a = Nothing | Just a 	-- Defined at <interactive>:1:1
-- instance [safe] Functor Maybe -- Defined at <interactive>:2:10

-- %%
:type \x -> return (x*10)
-- Out:
-- \x -> return (x*10) :: forall (m :: * -> *) a. (Num a, Monad m) => a -> m a

-- %%
:type return . (*10)
-- Out:
-- return . (*10) :: forall (m :: * -> *) a. (Num a, Monad m) => a -> m a
